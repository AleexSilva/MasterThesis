# %% [markdown]
# # Análisis y manipulación de datos

# %%
# Se importan las librerías que se van a utilizar

import pandas as pd
import re
import pickle as pk

# setting Jupyter

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',200)
pd.options.display.float_format= '{:.2f}'.format

# %% [markdown]
# ### Estructura de datos

# %%
#Se importa el diccionario creado en el archivo anterior
tweets = pk.load(open('Tweets','rb'))
tweets[0]
# Out:
# {'Autor_id': 1135944345591394304,
#  'Usuario': 'MaldonadoPoty',
#  'Seguidores_autor': 148,
#  'Tweets_autor': 2497,
#  'Descripcion_autor': '',
#  'Locacion_autor': None,
#  'Texto': '*Te ganarás la vacuna con el sudor de tu frente*\nBajo una lógica cruel e inhumana, la empresa Rappi Colombia desafió a sus “colaboradores” para que compitan por una vacuna contra la covid.\nhttps://t.co/pqgeNKoE3c https://t.co/ER295HOma4',
#  'Fecha': datetime.datetime(2021, 6, 30, 23, 41, 36, tzinfo=datetime.timezone.utc),
#  'Retweets': 0,
#  'Respuestas': 0,
#  'Likes': 1,
#  'Cant_citas': 0,
#  'Fuente': 'Twitter for Android'}

# %%
# Tranformar el diccionario en un DataFrame
df = pd.DataFrame(tweets)
df.head()
# Out:
#               Autor_id          Usuario  Seguidores_autor  Tweets_autor  \
# 0  1135944345591394304    MaldonadoPoty               148          2497
# 1  1048219845987323905  MikeEhrmantrau5                48          1393
# 2           3376611622     agabrielav27              5027         36925
# 3            134477385  ingmatiasvenier              1365         13298
# 4            335918975      edgar702010              4167         70406
#
#                                    Descripcion_autor  \
# 0
# 1                                                  😑
# 2  Mamá feliz.. Amo las cosas simples de la vida ...
# 3  Ingeniero Agrónomo,MSc Viticultura&Enología,ít...
# 4  Si no sueltas el pasado con qué manos agarras ...
#
#                Locacion_autor  \
# 0                        None
# 1     Albuquerque, La Matanza
# 2            Jujuy, Argentina
# 3  Gral. San Martín - Mendoza
# 4       Río Grande, Argentina
#
#                                                Texto  \
# 0  *Te ganarás la vacuna con el sudor de tu frent...
# 1  @ErwinSchrdngr @buccinito @Dianacos @msalnacio...
# 2  Después de la vacuna contra covid aconsejan no...
# 3  Presidente de la Nacion: Vacuna COVID para men...
# 4  @maximilianoreyz @alferdez @EstadioAzteca @Car...
#
#                       Fecha  Retweets  Respuestas  Likes  Cant_citas  \
# 0 2021-06-30 23:41:36+00:00         0           0      1           0
# 1 2021-06-30 23:24:12+00:00         1           1      5           0
# 2 2021-06-30 23:04:50+00:00         1           0      1           0
# 3 2021-06-30 22:23:17+00:00         0           0      0           0
# 4 2021-06-30 22:22:27+00:00         0           0      0           0
#
#                 Fuente
# 0  Twitter for Android
# 1  Twitter for Android
# 2  Twitter for Android
# 3   Twitter for iPhone
# 4  Twitter for Android

# %%
# Tipo de datos
df.dtypes
# Out:
# Autor_id                           int64
# Usuario                           object
# Seguidores_autor                   int64
# Tweets_autor                       int64
# Descripcion_autor                 object
# Locacion_autor                    object
# Texto                             object
# Fecha                datetime64[ns, UTC]
# Retweets                           int64
# Respuestas                         int64
# Likes                              int64
# Cant_citas                         int64
# Fuente                            object
# dtype: object

# %% [markdown]
# ## Entendimineto de datos

# %%
# Filas y columnas
print(f'En este Dataset hay {df.shape[0]} filas y {df.shape[1]} columnas.')
# Out:
# En este Dataset hay 3010 filas y 13 columnas.

# %%
df['Texto'].head(20)
# Out:
# 0     *Te ganarás la vacuna con el sudor de tu frent...
# 1     @ErwinSchrdngr @buccinito @Dianacos @msalnacio...
# 2     Después de la vacuna contra covid aconsejan no...
# 3     Presidente de la Nacion: Vacuna COVID para men...
# 4     @maximilianoreyz @alferdez @EstadioAzteca @Car...
# 5     Ser funcionario te protege más  contra el COVI...
# 6     Si les interesa saber sobre las vacunas cubana...
# 7     Hoy Es Un Muy Pero Muy Hermoso Dia 😀😀🥳🥳😊😊: Mi ...
# 8     @elbosnio @ngadano Te lo resumo: "ellos" no so...
# 9     Llegué a la primer dosis de vacuna sin haberme...
# 10    @Baneste_lab @JosefinaCanale @ergasto Eso no e...
# 11    Presidente de la Nacion: Vacuna COVID para men...
# 12    @CamilaM37706694 @FVoraces @NikMartini @MDSuar...
# 13    Con mucha emoción y alegría hoy recibí mi prim...
# 14    Hoy llegaron muchísimos SMS para confirmar tur...
# 15    Presidente de la Nación: Vacuna COVID para men...
# 16    Ya vacunado contra el covid-19 gracias a los c...
# 17    @BonzoWow @PatoBullrich Si todos vienen de vac...
# 18    Quiero confirmar que los efectos secundarios d...
# 19    Presidente de la Nacion: Vacuna COVID para men...
# Name: Texto, dtype: object

# %%
df['Locacion_autor'].value_counts()[:10]
# Out:
# Buenos Aires, Argentina           183
# Ciudad Autónoma de Buenos Aire    172
# Argentina                         142
# Córdoba, Argentina                 74
# Rosario, Argentina                 58
# Buenos Aires                       40
# La Plata, Argentina                39
# Campana, Argentina                 31
# República Argentina                28
# argentina                          26
# Name: Locacion_autor, dtype: int64

# %%
df['Locacion_autor'].value_counts().shape[0]
# Out:
# 782

# %%
df['Descripcion_autor'].tail(20)
# Out:
# 2990    👩🏻‍💻 Directora y Agente de Prensa en @dosdosun...
# 2991    liberal.  Agnóstico. Roquista. Fana del rugby ...
# 2992    cumpleaños 13 de agosto .leonina y de Racing.q...
# 2993
# 2994
# 2995                             Decoradora de interiores
# 2996    Fundador de ¨El Baqueano¨, “Cocina SIN Fronter...
# 2997    estoy en una etapa donde para ofenderme, prime...
# 2998    Odontóloga .Directora general de  D.Humanos de...
# 2999    Odontóloga .Directora general de  D.Humanos de...
# 3000    🇦🇷\nLas 24 horas leo Política, pienso Política...
# 3001    Argentina, fanática de mi hijo, de River, amo ...
# 3002    Estudiante de Ciencias de la Educación UNLP\nT...
# 3003                     Nacido aquí,y sigo viviendo aquí
# 3004    |Roni / Judio Runner y Sionista. . Larga Vida ...
# 3005    Me parece una pelotudes que se tomen a Twitter...
# 3006
# 3007
# 3008    cumpleaños 13 de agosto .leonina y de Racing.q...
# 3009    El Estado no es la solución, es el problema. L...
# Name: Descripcion_autor, dtype: object

# %%
df['Fecha'].head(10)
# Out:
# 0   2021-06-30 23:41:36+00:00
# 1   2021-06-30 23:24:12+00:00
# 2   2021-06-30 23:04:50+00:00
# 3   2021-06-30 22:23:17+00:00
# 4   2021-06-30 22:22:27+00:00
# 5   2021-06-30 22:09:39+00:00
# 6   2021-06-30 21:29:56+00:00
# 7   2021-06-30 19:05:20+00:00
# 8   2021-06-30 17:57:44+00:00
# 9   2021-06-30 17:38:45+00:00
# Name: Fecha, dtype: datetime64[ns, UTC]

# %%
# Ratio de unicidad
def uniqueRate(data,initialColumn):    
  d = pd.DataFrame(columns={"Cantidad_únicos","Ratio_únicos"},index=data.columns)
  x = data.columns

  for i in data.columns:
    d.loc[i,"Cantidad_únicos"]=data[i].nunique()

  d["Ratio_únicos"]= d["Cantidad_únicos"] / data.shape[0]
  d["Ratio_únicos"] = d["Ratio_únicos"].astype(float) *100
  d["Ratio_únicos"] = round(d["Ratio_únicos"],2).astype(str) + "%"
  return d.sort_values(by="Cantidad_únicos",ascending=False)


uniqueRate(df,0)
# Out:
#                   Cantidad_únicos Ratio_únicos
# Fecha                        3007        99.9%
# Texto                        2999       99.63%
# Autor_id                     2047       68.01%
# Usuario                      2047       68.01%
# Tweets_autor                 1983       65.88%
# Descripcion_autor            1791        59.5%
# Seguidores_autor             1377       45.75%
# Locacion_autor                782       25.98%
# Likes                         107        3.55%
# Retweets                       57        1.89%
# Respuestas                     37        1.23%
# Cant_citas                     20        0.66%
# Fuente                          7        0.23%

# %%
# Fuente
df['Fuente'].value_counts()
# Out:
# Twitter for Android    2367
# Twitter for iPhone      486
# Instagram                63
# dlvr.it                  48
# Twitter for iPad         44
# Foursquare Swarm          1
# Foursquare                1
# Name: Fuente, dtype: int64

# %%
# Desarrollo del Tweet
df['Texto'].value_counts().head(10)
# Out:
# Vacuna contra el COVID-19 podría aplicarse para la esclerosis múltiple https://t.co/fMQEQTcTHT vía @uchile                                                                                                           3
# El Papa Francisco recibió la primer dosis de la vacuna contra el Covid-19 https://t.co/XdmElTdGpo                                                                                                                    2
# Prioridad en la vacuna COVID a las personas con discapacidad @carlavizzotti @msalnacion @CarlaCa... https://t.co/4rP8P5xXSJ vía @ChangeorgAR                                                                         2
# Millonaria argentina se vacuna en #EstadosUnidos y termina en "hotel sanitario" porteño por #COVID https://t.co/nAuwzPTX0a https://t.co/oevEweCS6x                                                                   2
# Perú anunció acuerdos de compra de la vacuna contra el COVID-19 con AstraZeneca y Sinopharm - Infobae https://t.co/oczaotUez7                                                                                        2
# El #PapaFrancisco, de 84 años, recibió la segunda dosis de la #vacuna contra el #coronavirus y está inmunizado, confirmó a Efe el portavoz Vaticano, Matteo Bruni https://t.co/Pv9CFD06Jy https://t.co/jOYoS4SzCo    2
# Presidente de la Nacion: Vacuna COVID para menores con discapacidad @ANMATsalud @carlavizzotti @SandraMTirado @fggalarraga @andiscapacidad - ¡Firmá la petición! https://t.co/He9R0Fs96G vía @ChangeorgAR            2
# Presidente de la Nacion: Vacuna COVID para menores con discapacidad @ANMATsalud @carlavizzotti @SandraMTirado @fggalarraga @andiscapacidad - ¡Firmá la petición! https://t.co/enFsaifwU2 vía @ChangeorgAR            2
# Presidente de la Nacion: Vacuna COVID para menores con discapacidad @ANMATsalud @carlavizzotti @SandraMTirado @fggalarraga @andiscapacidad - ¡Firmá la petición! https://t.co/ooBde4NgZW vía @ChangeorgAR            2
# CABA: a partir del viernes, los mayores de 80 años podrán anotarse para recibir la vacuna contra el COVID-19 - Infobae https://t.co/zrvnRYyDiA                                                                       2
# Name: Texto, dtype: int64

# %%
firma=df[df['Texto'].str.contains('¡Firmá la petición!')]

print(f'Existen {firma.shape[0]} registros con el texto "Firmá la petición"')
# Out:
# Existen 110 registros con el texto "Firmá la petición"

# %%
# Usuario
df['Usuario'].value_counts()
# Out:
# Mario_Moray        40
# ElsaKekita         28
# LADdigital         28
# adapd1             28
# dariomaceiras1     23
#                    ..
# soyunpugcarlino     1
# julymar0721         1
# flavioarandatw      1
# SilvinaMGomez       1
# patriciolauda       1
# Name: Usuario, Length: 2047, dtype: int64

# %%
# Análisis del usuario "Mario_Moray" el cual es quien mayor cantidad de tweets postea realcionado a este tema.
df[df['Autor_id']==246107898].head()
# Out:
#       Autor_id      Usuario  Seguidores_autor  Tweets_autor  \
# 20   246107898  Mario_Moray             11356         87990
# 42   246107898  Mario_Moray             11356         87990
# 136  246107898  Mario_Moray             11356         87990
# 772  246107898  Mario_Moray             11356         87990
# 787  246107898  Mario_Moray             11356         87990
#
#                                      Descripcion_autor  \
# 20   Producer & Senior Editor. #BreakingNews, #News...
# 42   Producer & Senior Editor. #BreakingNews, #News...
# 136  Producer & Senior Editor. #BreakingNews, #News...
# 772  Producer & Senior Editor. #BreakingNews, #News...
# 787  Producer & Senior Editor. #BreakingNews, #News...
#
#               Locacion_autor  \
# 20   Buenos Aires, Argentina
# 42   Buenos Aires, Argentina
# 136  Buenos Aires, Argentina
# 772  Buenos Aires, Argentina
# 787  Buenos Aires, Argentina
#
#                                                  Texto  \
# 20   #Putin ha declarado que se vacunó con la #Sput...
# 42   Quiénes pueden vacunarse sin turno en la provi...
# 136  Confirmado: si tuviste #COVID19 solo necesitas...
# 772  Vacunados con dos dosis de la #SputnikV (.@spu...
# 787  El Gobierno alcanzó un acuerdo para la compra ...
#
#                         Fecha  Retweets  Respuestas  Likes  Cant_citas  \
# 20  2021-06-30 09:32:09+00:00         0           0      0           0
# 42  2021-06-29 14:30:56+00:00         0           0      0           0
# 136 2021-06-24 12:36:21+00:00         0           0      0           0
# 772 2021-05-27 22:30:58+00:00         0           0      2           0
# 787 2021-05-27 09:00:10+00:00         0           1      0           0
#
#                Fuente
# 20   Twitter for iPad
# 42   Twitter for iPad
# 136  Twitter for iPad
# 772  Twitter for iPad
# 787  Twitter for iPad

# %%
# He notado que en la "descipción del autor" es posible reconocer a algunos autores que utilizan la plataforma para informar.
# Por lo tanto, he eliminado esos usuarios para realizar el análisis sólo con tweets que expresan opinión públoca. 
# Dicha limpieza le hecho identificando palabras como "Noticias", "Revista", "Diario" y "News". Aquellos autores que presentan esas palabras en su descripción, quedarán duera de este análisis.

df1 = df.copy()
df1['Descripcion_autor'] = df1.Descripcion_autor.str.upper()
print('Cantidad de tweets que se eliminarían por palabra clave:\n')
print(f"Noticia -> {df1[df1['Descripcion_autor'].str.contains('NOTICIAS')].shape[0]}")
print(f"Revista -> {df1[df1['Descripcion_autor'].str.contains('REVISTA')].shape[0]}")
print(f"Diario -> {df1[df1['Descripcion_autor'].str.contains('DIARIO')].shape[0]}")
print(f"News -> {df1[df1['Descripcion_autor'].str.contains('NEWS')].shape[0]}")
# Out:
# Cantidad de tweets que se eliminarían por palabra clave:
#
# Noticia -> 76
# Revista -> 4
# Diario -> 61
# News -> 42

# %%
df1 = df.copy()
df1['Texto'] = df1.Texto.str.upper()
print('Cantidad de tweets que se eliminarían por palabra clave:\n')
print(f"¡Firmá la petición! -> {df['Texto'].str.contains('¡Firmá la petición!').sum()}")
# Out:
# Cantidad de tweets que se eliminarían por palabra clave:
#
# ¡Firmá la petición! -> 110

# %% [markdown]
# ## Primeras conclusiones:
#
#
# * Cambios en la columna Fecha: Se elimina el componente correspondiente a la hora en este campo. únicamnete se mantiene la fecha, con formato "aaa-mm-dd".
# * Se crea una nueva variable llamada "Hora" que captura la hora en la que el tweet fue creado
# * Se crea otra nueva variable llamada "Mes" que registra únicamente el mes en le que el tweet fue creado.
# * Se eliminan los tweets en donde la descripción del ususario contenga las siguientes palabras clave:
# >* Revista
# >* Diario
# >* Noticias
# >* News
# * Se eliminan los tweets manifiesten en su contenido la palabra clave "¡Firmá la petición!"
# * Se eliminan los tweets que fueron creados mediante la siguiente fuente:
# >* dlvr.it
# >* Foursquare Swarm
# >* Foursquare

# %% [markdown]
# ## Limpieza de  datos

# %%
# Cambios en la columna "Fecha".

df['Fecha'] = df['Fecha'].astype(str)
df['Hora']  = df.Fecha.str[10:13] + "hs" #Se crea una columna nueva para saber la hora en la que se creó el tweet
df['Mes']  = df.Fecha.str[5:7] #Se crea una columna nueva para saber la hora en la que se creó el tweet
df['Fecha']  = df.Fecha.str[0:10] #Se crea una columna para extraer sólo la fecha de la cración del tweet
df['Fecha']= df['Fecha'].apply(pd.to_datetime)

di={'01':'Enero','03':'Marzo','02':'Febrero','04':'Abril','05':'Mayo','06':'Junio'}
df.replace({'Mes':di},inplace=True)
df.head()
# Out:
#               Autor_id          Usuario  Seguidores_autor  Tweets_autor  \
# 0  1135944345591394304    MaldonadoPoty               148          2497
# 1  1048219845987323905  MikeEhrmantrau5                48          1393
# 2           3376611622     agabrielav27              5027         36925
# 3            134477385  ingmatiasvenier              1365         13298
# 4            335918975      edgar702010              4167         70406
#
#                                    Descripcion_autor  \
# 0
# 1                                                  😑
# 2  Mamá feliz.. Amo las cosas simples de la vida ...
# 3  Ingeniero Agrónomo,MSc Viticultura&Enología,ít...
# 4  Si no sueltas el pasado con qué manos agarras ...
#
#                Locacion_autor  \
# 0                        None
# 1     Albuquerque, La Matanza
# 2            Jujuy, Argentina
# 3  Gral. San Martín - Mendoza
# 4       Río Grande, Argentina
#
#                                                Texto      Fecha  Retweets  \
# 0  *Te ganarás la vacuna con el sudor de tu frent... 2021-06-30         0
# 1  @ErwinSchrdngr @buccinito @Dianacos @msalnacio... 2021-06-30         1
# 2  Después de la vacuna contra covid aconsejan no... 2021-06-30         1
# 3  Presidente de la Nacion: Vacuna COVID para men... 2021-06-30         0
# 4  @maximilianoreyz @alferdez @EstadioAzteca @Car... 2021-06-30         0
#
#    Respuestas  Likes  Cant_citas               Fuente   Hora    Mes
# 0           0      1           0  Twitter for Android   23hs  Junio
# 1           1      5           0  Twitter for Android   23hs  Junio
# 2           0      1           0  Twitter for Android   23hs  Junio
# 3           0      0           0   Twitter for iPhone   22hs  Junio
# 4           0      0           0  Twitter for Android   22hs  Junio

# %%
df.shape
# Out:
# (3010, 15)

# %%
df['Descripcion_autor']=df.Descripcion_autor.str.upper()

words=['REVISTA','DIARIO','NOTICIA','NEWS']

for word in words:
    df=df.drop(df[(df['Descripcion_autor'].str.contains(word))].index)


words2=['¡Firmá la petición!']

for word2 in words2:
    df=df.drop(df[(df['Texto'].str.contains(word2))].index)


words3=['dlvr.it','Foursquare Swarm','Foursquare']

for word3 in words3:
    df=df.drop(df[(df['Fuente']==word3)].index)

# %% [markdown]
# ## Limpieza de datos - Texto

# %%
# Se crea una función para limpiar el texto presente en los tweets
def LimpiarTexto(texto):
    texto = re.sub('@[A-Za-z0–9]+', '', texto) # Eliminar "#" del texto
    texto = re.sub('#', '', texto) # Eliminar hashtags (#)
    texto = re.sub('@[\S]*', '', texto) #Eliminar menciones (@)
    texto = re.sub('\\n', '', texto) # Eliminar el caracter '\n'
    texto = re.sub('https?:\/\/\S+', '', texto) # Eliminar Hiperlinks (https:\)
    return texto

# Limpieza de tweets
df['Texto'] = df['Texto'].apply(LimpiarTexto)
df['Texto'] = df['Texto'].str.strip()
df['Texto'] = df['Texto'].str.strip('*')

# %%
df = df.reset_index()
#Nueva Variable: Cantidad de caracteres en un Tweet

longitud=[]
for i in range(0,len(df.Texto)):
    longitud.append(len(df.Texto[i]))

df['Long_Texto'] = longitud

# %%
df.head()
# Out:
#    index             Autor_id          Usuario  Seguidores_autor  \
# 0      0  1135944345591394304    MaldonadoPoty               148
# 1      1  1048219845987323905  MikeEhrmantrau5                48
# 2      2           3376611622     agabrielav27              5027
# 3      4            335918975      edgar702010              4167
# 4      5           2740303732          guoltPE              4744
#
#    Tweets_autor                                  Descripcion_autor  \
# 0          2497
# 1          1393                                                  😑
# 2         36925  MAMÁ FELIZ.. AMO LAS COSAS SIMPLES DE LA VIDA ...
# 3         70406  SI NO SUELTAS EL PASADO CON QUÉ MANOS AGARRAS ...
# 4         64684  PUEDES ENGAÑAR A TODO EL MUNDO ALGÚN TIEMPO. P...
#
#             Locacion_autor                                              Texto  \
# 0                     None  Te ganarás la vacuna con el sudor de tu frente...
# 1  Albuquerque, La Matanza  "Además, al momento, constató que sólo falleci...
# 2         Jujuy, Argentina  Después de la vacuna contra covid aconsejan no...
# 3    Río Grande, Argentina  QUE EL MUNDO SEPA QUIENES SON UDS. LACRASSer f...
# 4      La Plata, Argentina  Ser funcionario te protege más  contra el COVI...
#
#        Fecha  Retweets  Respuestas  Likes  Cant_citas               Fuente  \
# 0 2021-06-30         0           0      1           0  Twitter for Android
# 1 2021-06-30         1           1      5           0  Twitter for Android
# 2 2021-06-30         1           0      1           0  Twitter for Android
# 3 2021-06-30         0           0      0           0  Twitter for Android
# 4 2021-06-30         0           1      2           0  Twitter for Android
#
#     Hora    Mes  Long_Texto
# 0   23hs  Junio         186
# 1   23hs  Junio         196
# 2   23hs  Junio         146
# 3   22hs  Junio         104
# 4   22hs  Junio          70

# %%
# Se eliminan las columnas que no se van a utilizar

df.drop(columns=['index','Autor_id','Usuario','Descripcion_autor','Locacion_autor'],inplace=True)

# %%
df.head()
# Out:
#    Seguidores_autor  Tweets_autor  \
# 0               148          2497
# 1                48          1393
# 2              5027         36925
# 3              4167         70406
# 4              4744         64684
#
#                                                Texto      Fecha  Retweets  \
# 0  Te ganarás la vacuna con el sudor de tu frente... 2021-06-30         0
# 1  "Además, al momento, constató que sólo falleci... 2021-06-30         1
# 2  Después de la vacuna contra covid aconsejan no... 2021-06-30         1
# 3  QUE EL MUNDO SEPA QUIENES SON UDS. LACRASSer f... 2021-06-30         0
# 4  Ser funcionario te protege más  contra el COVI... 2021-06-30         0
#
#    Respuestas  Likes  Cant_citas               Fuente   Hora    Mes  \
# 0           0      1           0  Twitter for Android   23hs  Junio
# 1           1      5           0  Twitter for Android   23hs  Junio
# 2           0      1           0  Twitter for Android   23hs  Junio
# 3           0      0           0  Twitter for Android   22hs  Junio
# 4           1      2           0  Twitter for Android   22hs  Junio
#
#    Long_Texto
# 0         186
# 1         196
# 2         146
# 3         104
# 4          70

# %%
print(f"Cantidad de registros restantes: {df.shape[0]}")
# Out:
# Cantidad de registros restantes: 2707

# %% [markdown]
# ## Estadísitica Descriptiva

# %%
num = df[['Seguidores_autor','Tweets_autor','Retweets','Respuestas','Likes','cant_citas','Long_Texto']]
num.describe().transpose()
# Out:
#                    count     mean       std  min     25%      50%      75%  \
# Seguidores_autor 2734.00  4202.60  23934.63 0.00  207.00   726.00  2336.25
# Tweets_autor     2734.00 52649.02 177814.30 3.00 3768.50 12573.00 38544.25
# Retweets         2734.00     2.45     24.16 0.00    0.00     0.00     1.00
# Respuestas       2734.00     1.31     20.70 0.00    0.00     0.00     1.00
# Likes            2734.00    13.19    291.66 0.00    0.00     1.00     3.00
# cant_citas       2734.00     0.22      2.27 0.00    0.00     0.00     0.00
# Long_Texto       2734.00   170.25     72.44 6.00  107.00   169.00   238.00
#
#                         max
# Seguidores_autor  557859.00
# Tweets_autor     1676377.00
# Retweets             981.00
# Respuestas           969.00
# Likes              15059.00
# cant_citas            89.00
# Long_Texto           298.00

# %%
df.groupby(['Mes'])[['Retweets','Likes','Respuestas']].sum()
# Out:
#          Retweets  Likes  Respuestas
# Mes
# Abril        1264   4907         722
# Enero        1010   3295         268
# Febrero       917   3008         352
# Junio        1002   4435         631
# Marzo        1222   3775         453
# Mayo         1278  16633        1152

# %%
df.groupby(['Mes'])[['Seguidores_autor','Tweets_autor']].mean()
# Out:
#          Seguidores_autor  Tweets_autor
# Mes
# Abril             2506.73      40490.73
# Enero             8147.40     161904.88
# Febrero           3907.01      35891.37
# Junio             3822.60      35123.07
# Marzo             5751.41      37136.30
# Mayo              2551.54      29849.11

# %%
df.groupby(['Mes'])['Seguidores_autor'].count()
# Out:
#        Mes  Seguidores_autor
# 0    Abril               570
# 1    Enero               363
# 2  Febrero               411
# 3    Junio               591
# 4    Marzo               375
# 5     Mayo               424

# %%
df['Hora'].value_counts()#.orderby('index')
# Out:
#  14hs    187
#  17hs    181
#  18hs    172
#  16hs    171
#  23hs    169
#  15hs    164
#  00hs    159
#  01hs    155
#  22hs    149
#  21hs    148
#  19hs    140
#  02hs    139
#  13hs    137
#  12hs    136
#  20hs    134
#  11hs    100
#  03hs     89
#  04hs     50
#  10hs     41
#  05hs     33
#  09hs     18
#  08hs     13
#  06hs     12
#  07hs     10
# Name: Hora, dtype: int64

# %%
Texto = df['Texto']
DataFrame = df.copy()

# Se guarda sólo el texto para un porterior análisis de sentimientos
Archivo1 = open('Texto.pk','wb')
pk.dump(Texto,Archivo1)
Archivo1.close()

# Se guarda el DataFrame completo para un posterior análisis final
Archivo2 = open('DataFrame.pk','wb')
pk.dump(Texto,Archivo2)
Archivo2.close()
